# %% [markdown]
# # Customer Churn and Revenue Risk Analytics\n\nUse this notebook for presentation-quality EDA, screenshots, and polished business storytelling.

# %%
from src.data import load_telco_data, clean_telco_data\nfrom src.features import add_business_features\nfrom src.analysis import save_business_summaries\nfrom src.modeling import train_and_compare_models

# %%
df = load_telco_data('data/raw/Telco-Customer-Churn.csv')\ndf = clean_telco_data(df)\ndf = add_business_features(df)\ndf.head()

# %%
save_business_summaries(df, 'reports')\nresults = train_and_compare_models(df)\nresults['metrics_df']
